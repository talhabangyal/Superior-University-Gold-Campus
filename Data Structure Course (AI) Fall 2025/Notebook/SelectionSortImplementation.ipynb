# %%
def selection_sort(arr):
    # Traverse through all array elements
    for i in range(len(arr)):
        # Find the minimum element in the remaining unsorted portion
        min_index = i
        for j in range(i + 1, len(arr)):
            if arr[j] < arr[min_index]:
                min_index = j
        
        # Swap the found minimum element with the first element of the unsorted portion
        arr[i], arr[min_index] = arr[min_index], arr[i]

# Example usage:
arr = [64, 25, 12, 22, 11]
print("Un-Sorted array is:", arr)
selection_sort(arr)
print("Sorted array is:", arr)
# Out:
# Un-Sorted array is: [64, 25, 12, 22, 11]
# Sorted array is: [11, 12, 22, 25, 64]

# %%
def selection_sort(self):
    n = len(self.stack)
    for i in range(n):
        min_index = i
        for j in range(i + 1, n):
            if self.stack[j] < self.stack[min_index]:
                min_index = j
        if min_index != i:
            self.stack[i], self.stack[min_index] = self.stack[min_index], self.stack[i]
            print(self.stack)   # print only when a swap happens
        print("")
        print(f"After pass {i+1}: {self.stack}")
